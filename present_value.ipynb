# %%
# TODO consolidate all imports to agent0
# TODO wrap these calls in an interface for experiments
from ethpy.base import launch_local_chain
from ethpy.hyperdrive.api import HyperdriveInterface
from fixedpointmath import FixedPoint
from hypertypes.IHyperdriveTypes import Fees, PoolConfig
from web3.constants import ADDRESS_ZERO
from ethpy.hyperdrive import deploy_hyperdrive_from_factory
from ethpy import EthConfig
from agent0.hyperdrive.exec import async_fund_agents, create_and_fund_user_account
from agent0.base.make_key import make_private_key
from agent0.hyperdrive.agents import HyperdriveAgent
from eth_account.account import Account
from agent0 import AccountKeyConfig

# %%
# Hyperdrive initialization parameters

# ABI folder should contain JSON and Bytecode files for the following contracts:
# ERC20Mintable, MockERC4626, ForwarderFactory, ERC4626HyperdriveDeployer, ERC4626HyperdriveFactory
abi_dir = "../agent0/packages/hyperdrive/src/abis/"

# Deployer is the pre-funded account 0 on the Delv devnet
deployer_private_key: str = (
    "0xac0974bec39a17e36ba4a6b4d238ff944bacb478cbed5efcae784d7bf4f2ff80"
)

# Factory initializaiton parameters
initial_variable_rate = FixedPoint("0.05")
curve_fee = FixedPoint("0.1")  # 10%
flat_fee = FixedPoint("0.0005")  # 0.05%
governance_fee = FixedPoint("0.15")  # 15%
max_curve_fee = FixedPoint("0.3")  # 30%
max_flat_fee = FixedPoint("0.0015")  # 0.15%
max_governance_fee = FixedPoint("0.30")  # 30%

# Pool initialization parameters
initial_fixed_rate = FixedPoint("0.05")  # 5%
initial_liquidity = FixedPoint(100_000_000)  # 100M ETH
initial_share_price = FixedPoint(1)
minimum_share_reserves = FixedPoint(10)
minimum_transaction_amount = FixedPoint("0.001")
precision_threshold = int(1e14)
time_stretch = (
    FixedPoint("0.04665") * (initial_fixed_rate * FixedPoint(100))
) / FixedPoint("5.24592")
position_duration = 604800  # 1 week
checkpoint_duration = 3600  # 1 hour
oracle_size = 10
update_gap = 3600  # 1 hour

# Derived values
fees = Fees(curve_fee.scaled_value, flat_fee.scaled_value, governance_fee.scaled_value)
max_fees = Fees(
    max_curve_fee.scaled_value,
    max_flat_fee.scaled_value,
    max_governance_fee.scaled_value,
)
initial_pool_config = PoolConfig(
    "",  # will be determined in the deploy function
    ADDRESS_ZERO,  # address(0), this address needs to be in a valid address format
    bytes(32),  # bytes32(0)
    initial_share_price.scaled_value,
    minimum_share_reserves.scaled_value,
    minimum_transaction_amount.scaled_value,
    precision_threshold,
    position_duration,
    checkpoint_duration,
    time_stretch.scaled_value,
    "",  # will be determined in the deploy function
    "",  # will be determined in the deploy function
    fees,
)

# %%
# Run local chain and deploy hyperdrive with parameters

# TODO this function is yielding the anvil address, where the return call
# does cleanup. Fix this to be a stateful object for launching a local chain in a subprocess.
anvil_address_gen = launch_local_chain(anvil_port=9999)
anvil_address = next(anvil_address_gen)

# Initialize the hyperdrive interface and deploy the chain
# TODO this function is deploying both the factory and the initial pool.
# Should expose both factory deployment and initializing a pool from the factory.
hyperdrive_chain = deploy_hyperdrive_from_factory(
    anvil_address,
    abi_dir,
    deployer_private_key,
    initial_liquidity,
    initial_variable_rate,
    initial_fixed_rate,
    initial_pool_config,
    max_fees,
)

hyperdrive_interface = HyperdriveInterface(
    EthConfig(artifacts_uri="not used", rpc_uri=anvil_address, abi_dir=abi_dir),
    hyperdrive_chain.hyperdrive_contract_addresses,
)
# Out:
#                              _   _
#                             (_) | |
#       __ _   _ __   __   __  _  | |
#      / _` | | '_ \  \ \ / / | | | |
#     | (_| | | | | |  \ V /  | | | |
#      \__,_| |_| |_|   \_/   |_| |_|
#
#     0.1.0 (08a629a 2023-06-03T00:15:12.657002000Z)
#     https://github.com/foundry-rs/foundry
#
# Available Accounts
# ==================
#
# (0) "0xf39Fd6e51aad88F6F4ce6aB8827279cffFb92266" (10000.000000000000000000 ETH)
# (1) "0x70997970C51812dc3A010C7d01b50e0d17dc79C8" (10000.000000000000000000 ETH)
# (2) "0x3C44CdDdB6a900fa2b585dd299e03d12FA4293BC" (10000.000000000000000000 ETH)
# (3) "0x90F79bf6EB2c4f870365E785982E1f101E93b906" (10000.000000000000000000 ETH)
# (4) "0x15d34AAf54267DB7D7c367839AAf71A00a2C6A65" (10000.000000000000000000 ETH)
# (5) "0x9965507D1a55bcC2695C58ba16FB37d819B0A4dc" (10000.000000000000000000 ETH)
# (6) "0x976EA74026E726554dB657fA54763abd0C3a0aa9" (10000.000000000000000000 ETH)
# (7) "0x14dC79964da2C08b23698B3D3cc7Ca32193d9955" (10000.000000000000000000 ETH)
# (8) "0x23618e81E3f5cdF7f54C3d65f7FBc0aBf5B21E8f" (10000.000000000000000000 ETH)
# (9) "0xa0Ee7A142d267C1f36714E4a8F75612F20a79720" (10000.000000000000000000 ETH)
#
# Private Keys
# ==================
#
# (0) 0xac0974bec39a17e36ba4a6b4d238ff944bacb478cbed5efcae784d7bf4f2ff80
# (1) 0x59c6995e998f97a5a0044966f0945389dc9e86dae88c7a8412f4603b6b78690d
# (2) 0x5de4111afa1a4b94908f83103eb1f1706367c2e68ca870fc3fb9a804cdab365a
# (3) 0x7c852118294e51e653712a81e05800f419141751be58f605c371e15141b007a6
# (4) 0x47e179ec197488593b187f80a00eb0da91f1b9d0b13f8733639f19c30a34926a
# (5) 0x8b3a350cf5c34c9194ca85829a2df0ec3153be0318b5e2d3348e872092edffba
# (6) 0x92db14e403b83dfe3df233f83dfa3a0d7096f21ca9b0d6d6b8d88b2b4ec1564e
# (7) 0x4bbbf85ce3377467afe5d46f804f221813b2bb87f24d81f60f1fcdbf7cbf4356
# (8) 0xdbda1821b80551c9d65939329250298aa3472ba22feea921c0cf5d620ea67b97
# (9) 0x2a871d0798f97d79848a013d4936a73bf4cc922c825d33c1cf7073dff6d409c6
#
# Wallet
# ==================
# Mnemonic:          test test test test test test test test test test test junk
# Derivation path:   m/44'/60'/0'/0/
#
#
# Base Fee
# ==================
#
# 1000000000
#
# Gas Limit
# ==================
#
# 30000000
#
# Genesis Timestamp
# ==================
#
# 1700180840
#
# Listening on 127.0.0.1:9999
# eth_accounts
# eth_getBlockByNumber
# eth_chainId
# eth_chainId
# eth_estimateGas
# eth_blockNumber
# eth_getBlockByNumber
# eth_sendTransaction
#
#     Transaction: 0x361ff515bb614cfa160fcdfa992c6a8d7fccf58fd71c890b87a44a117c1c5c60
#     Contract created: 0x5fbdb2315678afecb367f032d93f642f64180aa3
#     Gas used: 1497409
#
#     Block Number: 1
#     Block Hash: 0x7e195388c7a5df58429e241689044cbcb07a897fd8c9b2d8444fa4502a4c210c
#     Block Time: "Fri, 17 Nov 2023 00:27:23 +0000"
#
# eth_getTransactionReceipt
# eth_getBlockByNumber
# eth_chainId
# eth_chainId
# eth_estimateGas
# eth_blockNumber
# eth_getBlockByNumber
# eth_sendTransaction
#
#     Transaction: 0x5f5d13e06ff0c1921be7cbe53d8f6b1062083ecd17ffd3fa97748b6c258bf0d2
#     Contract created: 0xe7f1725e7734ce288f8367e1bb143e90bb3f0512
#     Gas used: 2055625
#
#     Block Number: 2
#     Block Hash: 0xdfc5f08828c6fac87ad25fcb41fab4e7173060465d80325991052ef455296b37
#     Block Time: "Fri, 17 Nov 2023 00:27:24 +0000"
#
# eth_getTransactionReceipt
# eth_getBlockByNumber
# eth_chainId
# eth_chainId
# eth_estimateGas
# eth_blockNumber
# eth_getBlockByNumber
# eth_sendTransaction
#
#     Transaction: 0xebb5714c5f5a633f52b6e4d572ccab61dd3b326d3f39e609730c63aab85720dc
#     Contract created: 0x9fe46736679d2d9a65f0992f2272de9f3c7fa6e0
#     Gas used: 1300147
#
#     Block Number: 3
#     Block Hash: 0xf9900d9c79d6d8241ea255fc6f1bbb121e955c0d7129ecb38c158c00d1b30d55
#     Block Time: "Fri, 17 Nov 2023 00:27:25 +0000"
#
# eth_getTransactionReceipt
# eth_getBlockByNumber
# eth_chainId
# eth_chainId
# eth_estimateGas
# eth_blockNumber
# eth_getBlockByNumber
# eth_sendTransaction
#
#     Transaction: 0xa040847531b507e0176452ab7550f075c33768919e3f498c46cd8295bd03b3c8
#     Contract created: 0xcf7ed3acca5a467e9e704c703e8d87f634fb0fc9
#     Gas used: 4418647
#
#     Block Number: 4
#     Block Hash: 0x109329e87d85348aaa09be48f45480d8837d000a29f61a72281ac05607dc06f7
#     Block Time: "Fri, 17 Nov 2023 00:27:26 +0000"
#
# eth_getTransactionReceipt
# eth_getBlockByNumber
# eth_chainId
# eth_chainId
# eth_estimateGas
# eth_blockNumber
# eth_getBlockByNumber
# eth_sendTransaction
#
#     Transaction: 0xd43fc49221476e5c2d90aa506b69fd98772d3a810c1c6023b986c3253bab7b34
#     Contract created: 0xdc64a140aa3e981100a9beca4e685f962f0cf6c9
#     Gas used: 3250871
#
#     Block Number: 5
#     Block Hash: 0x1e5347fad799986613ee4d14686cdcc065171692391f55e27f55ee1b36bfc67d
#     Block Time: "Fri, 17 Nov 2023 00:27:27 +0000"
#
# eth_getTransactionReceipt
# eth_getBlockByNumber
# eth_chainId
# eth_chainId
# eth_estimateGas
# eth_blockNumber
# eth_getBlockByNumber
# eth_sendTransaction
#
#     Transaction: 0xd4d4404e5ff8fa9ab21dd487da038fe06454e4a64dbb37afdf493c2ef7ba0b0b
#     Contract created: 0x5fc8d32690cc91d4c39d9d3abcbd16989f875707
#     Gas used: 4148266
#
#     Block Number: 6
#     Block Hash: 0x67346e27ae3e8a63d3a24772357b9c79cf2210ef97fb7cb2e3603cc243c0935c
#     Block Time: "Fri, 17 Nov 2023 00:27:28 +0000"
#
# eth_getTransactionReceipt
# eth_chainId
# eth_call
# eth_getBlockByNumber
# eth_chainId
# eth_chainId
# eth_estimateGas
# eth_blockNumber
# eth_getBlockByNumber
# eth_sendTransaction
#
#     Transaction: 0xdc0b41c4f28ca0c83603faaf309712a8a854132b29420caec71768ec1206ee16
#     Contract created: 0x0165878a594ca255338adfa4d48449f69242eb8f
#     Gas used: 1760290
#
#     Block Number: 7
#     Block Hash: 0x62f546f8ca603dc58a88fce4ad50cfb1b9272677bde4ea029b236ae3fa1b2c68
#     Block Time: "Fri, 17 Nov 2023 00:27:29 +0000"
#
# eth_getTransactionReceipt
# eth_getTransactionCount
# eth_chainId
# eth_estimateGas
# eth_getBlockByNumber
# eth_chainId
# eth_sendRawTransaction
#
#     Transaction: 0x2e979577478168bebf73167ba1e2c9a173cb8e946fe57ab23f1a049c8164c79d
#     Gas used: 68345
#
#     Block Number: 8
#     Block Hash: 0x75d1f315d635062cf4929048175a78e7c03ac5f582c5154ea67f331c0e5eaf41
#     Block Time: "Fri, 17 Nov 2023 00:27:30 +0000"
#
# eth_getTransactionReceipt
# eth_getTransactionCount
# eth_chainId
# eth_estimateGas
# eth_getBlockByNumber
# eth_chainId
# eth_sendRawTransaction
#
#     Transaction: 0x04258e6b42813dfe9e9108d64bb51cb96a5934e950a85f1f938fbc171894c36f
#     Gas used: 46241
#
#     Block Number: 9
#     Block Hash: 0xb36bfadfa9db96ac95172379f7776ac9f8801dd7e344bc80173e339ce6fb5300
#     Block Time: "Fri, 17 Nov 2023 00:27:31 +0000"
#
# eth_getTransactionReceipt
# eth_getTransactionCount
# eth_chainId
# eth_estimateGas
# eth_getBlockByNumber
# eth_chainId
# eth_sendRawTransaction
# eth_getTransactionReceipt
#
#     Transaction: 0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7
#     Gas used: 9808454
#
#     Block Number: 10
#     Block Hash: 0xbe4c38db138ef41245903de22cac18be2c17a377f5169d490c2ea833a24cd838
#     Block Time: "Fri, 17 Nov 2023 00:27:32 +0000"
#
# eth_getTransactionReceipt
# eth_chainId
# eth_call
# eth_getBlockByNumber
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 0 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 1 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 2 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 3 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 4 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 5 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 6 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 7 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 8 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 9 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 10 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(
# /Users/slundquist/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/base_contract.py:185: UserWarning: The log with transaction hash: HexBytes('0x075492621354d81a5d3a14047f557391867026e574ff3b6302e61e9d0bd84fc7') and logIndex: 11 encountered the following error during processing: MismatchedABI(The event signature did not match the provided ABI). It has been discarded.
#   warnings.warn(

# %%
# Set up agents
num_agents = 1
eth_budgets = [
    1 * 10**18,
] * num_agents
base_budgets = [
    50_000 * 10**18,
] * num_agents

agents: list[HyperdriveAgent] = []
for _ in range(num_agents):
    user_private_key = make_private_key()
    agents.append(HyperdriveAgent(Account().from_key(user_private_key)))

account_config = AccountKeyConfig(
    deployer_private_key,
    [agent._private_key for agent in agents],  # pylint: disable=protected-access
    eth_budgets,
    base_budgets,
)

# Fund accounts
user_account = create_and_fund_user_account(hyperdrive_interface.eth_config, account_config, hyperdrive_chain.hyperdrive_contract_addresses)
await async_fund_agents(
    user_account,
    hyperdrive_interface.eth_config,
    account_config,
    hyperdrive_chain.hyperdrive_contract_addresses,
)
# Out:
# WARNING:root:Policy random number generator (rng) argument not set, using seed of `123`.
# WARNING:root:Policy random number generator (rng) argument not set, using seed of `123`.
# eth_chainId
# eth_call
# anvil_setBalance
# eth_getTransactionCount
# eth_chainId
# eth_estimateGas
# eth_getBlockByNumber
# eth_chainId
# eth_sendRawTransaction
#
#     Transaction: 0xe7ef802f05a1b3ee680bfa1f87aa56af020a05b9a878df2cb705b1d352762b03
#     Gas used: 51245
#
#     Block Number: 11
#     Block Hash: 0xf7ca4d9c96743e5c64318fa7956331446926ccd65835fa39822f2119dc4ef374
#     Block Time: "Fri, 17 Nov 2023 00:27:33 +0000"
#
# eth_getTransactionReceipt
#
# 23-11-16 16:27:25: WARNING: base.__init__:
# Policy random number generator (rng) argument not set, using seed of `123`.
# eth_getBalance
# eth_chainId
# eth_call
#
# 23-11-16 16:27:25: INFO: fund_agents.async_fund_agents:
# Funding Eth
# eth_getTransactionCount
# eth_getTransactionCount
# eth_chainId
# eth_getBlockByNumber
# eth_chainId
# eth_estimateGas
# eth_sendRawTransaction
#
#     Transaction: 0x59196bb9734d7cdc4db72bbf99b7a1a976eda4dc33b7bbd02ebb7506b0e89830
#     Gas used: 21000
#
#     Block Number: 12
#     Block Hash: 0x5afba2af23278af3804030dd78cc0e40a8793109011a735a229cd874baf801b7
#     Block Time: "Fri, 17 Nov 2023 00:27:34 +0000"
#
# eth_getTransactionReceipt
#
# 23-11-16 16:27:25: INFO: fund_agents.async_fund_agents:
# Funding Base
# eth_getTransactionCount
# eth_getTransactionCount
# eth_chainId
# eth_estimateGas
# eth_getBlockByNumber
# eth_chainId
# eth_sendRawTransaction
#
#     Transaction: 0xe75b77988bb8616282c596b6644ce1e53f6258e052f01a3faaf69c4a2ed7937d
#     Gas used: 51380
#
#     Block Number: 13
#     Block Hash: 0x9298280bd5d675e86e46794985192aece985132ac3c6818767dd4ea467697ce3
#     Block Time: "Fri, 17 Nov 2023 00:27:35 +0000"
#
# eth_getTransactionReceipt
#
# 23-11-16 16:27:25: INFO: fund_agents.async_fund_agents:
# Accounts funded

# %%
# execute trades
lp_agent_index = 0
trade_result = hyperdrive_interface.async_add_liquidity(
    agent=agents[lp_agent_index],
    trade_amount=FixedPoint(1000),
    min_apr=FixedPoint("0.001"),
    max_apr=FixedPoint("1.0"),
)

# TODO either expose the non-async version of this function or wrap these calls in something
trade_result = await hyperdrive_interface.async_open_long(
    agent=agents[0], trade_amount=FixedPoint(100), slippage_tolerance=FixedPoint("0.1")
)

trade_result = await hyperdrive_interface.async_open_short(
    agent=agents[0], trade_amount=FixedPoint(10), slippage_tolerance=FixedPoint("0.1")
)
# Out:
# eth_getBlockByNumber
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# eth_chainId
# eth_call
# eth_chainId
# eth_estimateGas
# eth_chainId
# eth_call
# ---------------------------------------------------------------------------
# ContractLogicError                        Traceback (most recent call last)
# File ~/workspace/agent0/lib/ethpy/ethpy/base/transactions.py:197, in smart_contract_preview_transaction(contract, signer_address, function_name_or_signature, block_number, read_retry_count, *fn_args, **fn_kwargs)
#     196 try:
# --> 197     return_values = retry_call(
#     198         read_retry_count,
#     199         _retry_preview_check,
#     200         function.call,
#     201         transaction_kwargs,
#     202         block_identifier=block_number,
#     203     )
#     204 # Wraps the exception with a contract call exception, adding additional information
#     205 # If block number is set in the preview call, will add to crash report,
#     206 # otherwise will do best attempt at getting the block it crashed at.
#
# File ~/workspace/agent0/lib/ethpy/ethpy/base/retry_utils.py:110, in retry_call(retry_count, retry_exception_check, func, *args, **kwargs)
#     109 if retry_exception_check is not None and not retry_exception_check(exc):
# --> 110     raise exc
#     111 # Get caller of this function's name
#
# File ~/workspace/agent0/lib/ethpy/ethpy/base/retry_utils.py:104, in retry_call(retry_count, retry_exception_check, func, *args, **kwargs)
#     103 try:
# --> 104     out = func(*args, **kwargs)
#     105     return out
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/contract.py:305, in ContractFunction.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     303 block_id = parse_block_identifier(self.w3, block_identifier)
# --> 305 return call_contract_function(
#     306     self.w3,
#     307     self.address,
#     308     self._return_data_normalizers,
#     309     self.function_identifier,
#     310     call_transaction,
#     311     block_id,
#     312     self.contract_abi,
#     313     self.abi,
#     314     state_override,
#     315     ccip_read_enabled,
#     316     self.decode_tuples,
#     317     *self.args,
#     318     **self.kwargs,
#     319 )
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/contract/utils.py:96, in call_contract_function(w3, address, normalizers, function_identifier, transaction, block_id, contract_abi, fn_abi, state_override, ccip_read_enabled, decode_tuples, *args, **kwargs)
#      85 call_transaction = prepare_transaction(
#      86     address,
#      87     w3,
#    (...)
#      93     fn_kwargs=kwargs,
#      94 )
# ---> 96 return_data = w3.eth.call(
#      97     call_transaction,
#      98     block_identifier=block_id,
#      99     state_override=state_override,
#     100     ccip_read_enabled=ccip_read_enabled,
#     101 )
#     103 if fn_abi is None:
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/eth/eth.py:256, in Eth.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     247 if (
#     248     # default conditions:
#     249     ccip_read_enabled_on_provider
#    (...)
#     254     and ccip_read_enabled is True
#     255 ):
# --> 256     return self._durin_call(transaction, block_identifier, state_override)
#     258 return self._call(transaction, block_identifier, state_override)
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/eth/eth.py:275, in Eth._durin_call(self, transaction, block_identifier, state_override)
#     274 try:
# --> 275     return self._call(transaction, block_identifier, state_override)
#     276 except OffchainLookup as offchain_lookup:
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/module.py:75, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#      70 (
#      71     result_formatters,
#      72     error_formatters,
#      73     null_result_formatters,
#      74 ) = response_formatters
# ---> 75 result = w3.manager.request_blocking(
#      76     method_str, params, error_formatters, null_result_formatters
#      77 )
#      78 return apply_result_formatters(result_formatters, result)
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/manager.py:325, in RequestManager.request_blocking(self, method, params, error_formatters, null_result_formatters)
#     324 response = self._make_request(method, params)
# --> 325 return self.formatted_response(
#     326     response, params, error_formatters, null_result_formatters
#     327 )
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/manager.py:286, in RequestManager.formatted_response(response, params, error_formatters, null_result_formatters)
#     282     _raise_bad_response_format(
#     283         response, "error['message'] must be a string"
#     284     )
# --> 286 apply_error_formatters(error_formatters, response)
#     288 raise ValueError(error)
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/manager.py:103, in apply_error_formatters(error_formatters, response)
#     102 if error_formatters:
# --> 103     formatted_resp = pipe(response, error_formatters)
#     104     return formatted_resp
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:680, in cytoolz.functoolz.pipe()
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:655, in cytoolz.functoolz.c_pipe()
#
# File ~/workspace/hyperdrive-experiments/.venv/lib/python3.10/site-packages/web3/_utils/contract_error_handling.py:161, in raise_contract_logic_error_on_revert(response)
#     160 if error.get("code") == 3:
# --> 161     raise ContractLogicError(message, data=data)
#     162 # Geth Revert without error message case:
#
# ContractLogicError: execution reverted: TRANSFER_FROM_FAILED
#
# The above exception was the direct cause of the following exception:
#
# ContractCallException                     Traceback (most recent call last)
# /Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb Cell 5 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> trade_result = hyperdrive_interface.async_add_liquidity(
#       <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     agent=agents[lp_agent_index],
#       <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     trade_amount=FixedPoint(1000),
#       <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     min_apr=FixedPoint("0.001"),
#       <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     max_apr=FixedPoint("1.0"),
#       <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> # TODO either expose the non-async version of this function or wrap these calls in something
# ---> <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> trade_result = await hyperdrive_interface.async_open_long(
#      <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     agent=agents[0], trade_amount=FixedPoint(100), slippage_tolerance=FixedPoint("0.1")
#      <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> trade_result = await hyperdrive_interface.async_open_short(
#      <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     agent=agents[0], trade_amount=FixedPoint(10), slippage_tolerance=FixedPoint("0.1")
#      <a href='vscode-notebook-cell://ssh-remote%2B10.0.0.143/Users/slundquist/workspace/hyperdrive-experiments/present_value.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> )
#
# File ~/workspace/agent0/lib/ethpy/ethpy/hyperdrive/api/api.py:380, in HyperdriveInterface.async_open_long(self, agent, trade_amount, slippage_tolerance, nonce)
#     353 async def async_open_long(
#     354     self,
#     355     agent: LocalAccount,
#    (...)
#     358     nonce: Nonce | None = None,
#     359 ) -> ReceiptBreakdown:
#     360     """Contract call to open a long position.
#     361
#     362     Arguments
#    (...)
#     378         A dataclass containing the maturity time and the absolute values for token quantities changed.
#     379     """
# --> 380     return await _async_open_long(self, agent, trade_amount, slippage_tolerance, nonce)
#
# File ~/workspace/agent0/lib/ethpy/ethpy/hyperdrive/api/_contract_calls.py:109, in _async_open_long(interface, agent, trade_amount, slippage_tolerance, nonce)
#     105 # To catch any solidity errors, we always preview transactions on the current block
#     106 # before calling smart contract transact
#     107 # Since current_pool_state.block_number is a property, we want to get the static block here
#     108 current_block = interface.current_pool_state.block_number
# --> 109 preview_result = smart_contract_preview_transaction(
#     110     interface.hyperdrive_contract,
#     111     agent_checksum_address,
#     112     "openLong",
#     113     *fn_args,
#     114     block_number=current_block,
#     115     read_retry_count=interface.read_retry_count,
#     116 )
#     117 if slippage_tolerance is not None:
#     118     min_output = (
#     119         FixedPoint(scaled_value=preview_result["bondProceeds"]) * (FixedPoint(1) - slippage_tolerance)
#     120     ).scaled_value
#
# File ~/workspace/agent0/lib/ethpy/ethpy/base/transactions.py:220, in smart_contract_preview_transaction(contract, signer_address, function_name_or_signature, block_number, read_retry_count, *fn_args, **fn_kwargs)
#     209     raise ContractCallException(
#     210         "Error in preview transaction",
#     211         orig_exception=err,
#    (...)
#     217         block_number=block_number,
#     218     ) from err
#     219 except Exception as err:
# --> 220     raise ContractCallException(
#     221         "Error in preview transaction",
#     222         orig_exception=err,
#     223         contract_call_type=ContractCallType.PREVIEW,
#     224         function_name_or_signature=function_name_or_signature,
#     225         fn_args=fn_args,
#     226         fn_kwargs=fn_kwargs,
#     227         raw_txn=dict(raw_txn),
#     228         block_number=block_number,
#     229     ) from err
#     231 if not isinstance(return_values, Sequence):  # could be list or tuple
#     232     return_values = [return_values]
#
# ContractCallException: Error in preview transaction
